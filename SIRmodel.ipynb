# %% [markdown]
# # MODELLING DISEASE SPREAD WITH SYSTEM OF DIFFERENTIAL EQUATIONS

# %% [markdown]
# In this notebook we will explore the basics of modelling disease spread via systems of differential equations. This is comparable to what we did in chapter 2 with population models.The model we will look at is called the SIR model. The model is three dimemnsional with the three variables being:
# 1. S: Susceptible population. The current population who is healthy but could be infected
# 2. I: Infected population. The population that is currently infected
# 3. R: Recovered(or removed) Population. This variable represents the people who are recovered(or died) so can't get the disease again
#
#
# This model assumes that people can't be re infected and the total population is constant.
#
# It will be helpful to let N be the total population and
# 1. s : S/N
# 2. i : I/N
# 3. r : R/N
# Be the fraction of each population that is in each class.
#
# ## Exercise 1
# Roughly what should we expect of S's long term behavior(i.e. does it increase, decrease or flucate)?
#
# ## Exercise 2
# Roughly what should we expect of R's long term behavior(i.e. does it increase, decrease or flucate)?
#
#
# ## Exercise 3
# How should we expect I to change with respect to S and R?

# %% [markdown]
# ## The differential equations
# We will want to derive a system of differential equations that govern the change of each variable over time. If you did the above exercises you will have already built up a lot of the intuition for this model.
#
# ### dS/dt
# Hopefully you figured that the change in S should be negative since S is only decreasing. Furthermore you might have figured that the number of new infected people should depend on how likely it is that an infected person and a healthy person come into contact with eachother. So we guess that the model looks like:
# 1. dS/dt = -k_1 S I / N
#
# Where k_1 is a constant and SI/N represents how likely it is that a sick and healthy individual interact assuming people interact. In real life k_1 is determined by how many interactions the average person has but how likely it is that an interaction leads to an infection.
#
# ### dR/dt
# We'll skip dI/dt for now and come back to it. The rate of change for R should be 1) non-decreasing 2) should depend only on how many currently infected people there. So we would expect that
# dR/dt = k_2 I
#
# ### Exercise 4
# Using the fact that the population is constant derive the expression for dI/dt
#
# ### Exercise 5
# Write this as a system of differential equations of the form
# [dS, dI, dR]^T = A [S, I , R]^T
#
# Let's explore how this simple model works in real life.
#
#
# If you have python installed already follow along.

# %%
from ipywidgets import interact # Optional
try:
    import matplotlib
except:
    # !pip install matplotlib

try:
    import nbinteract
except:
    # !pip install nbinteract
import matplotlib.pyplot as plt
# Out:
# Collecting nbinteract
#   Using cached nbinteract-0.2.5-py3-none-any.whl (29 kB)
# Collecting nbformat<5,>=4.4.0
#   Using cached nbformat-4.4.0-py2.py3-none-any.whl (155 kB)
# Requirement already satisfied: Jinja2<3,>=2.10 in /home/calvin/anaconda3/lib/python3.8/site-packages (from nbinteract) (2.11.2)
# Collecting traitlets<5,>=4.3
#   Using cached traitlets-4.3.3-py2.py3-none-any.whl (75 kB)
# Requirement already satisfied: toolz<1,>=0.8 in /home/calvin/anaconda3/lib/python3.8/site-packages (from nbinteract) (0.11.1)
# Collecting nbconvert<6,>=5.3
#   Using cached nbconvert-5.6.1-py2.py3-none-any.whl (455 kB)
# Requirement already satisfied: ipywidgets<8,>=7.5.0 in /home/calvin/anaconda3/lib/python3.8/site-packages (from nbinteract) (7.5.1)
# Requirement already satisfied: numpy<2,>=1 in /home/calvin/anaconda3/lib/python3.8/site-packages (from nbinteract) (1.19.2)
# Processing /home/calvin/.cache/pip/wheels/9b/04/dd/7daf4150b6d9b12949298737de9431a324d4b797ffd63f526e/docopt-0.6.2-py2.py3-none-any.whl
# Collecting bqplot==0.11.0
#   Using cached bqplot-0.11.0-py2.py3-none-any.whl (1.5 MB)
# Requirement already satisfied: IPython<8,>=6 in /home/calvin/anaconda3/lib/python3.8/site-packages (from nbinteract) (7.19.0)
# Requirement already satisfied: ipython-genutils in /home/calvin/anaconda3/lib/python3.8/site-packages (from nbformat<5,>=4.4.0->nbinteract) (0.2.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /home/calvin/anaconda3/lib/python3.8/site-packages (from nbformat<5,>=4.4.0->nbinteract) (3.2.0)
# Requirement already satisfied: jupyter-core in /home/calvin/anaconda3/lib/python3.8/site-packages (from nbformat<5,>=4.4.0->nbinteract) (4.6.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/calvin/anaconda3/lib/python3.8/site-packages (from Jinja2<3,>=2.10->nbinteract) (1.1.1)
# Requirement already satisfied: six in /home/calvin/anaconda3/lib/python3.8/site-packages (from traitlets<5,>=4.3->nbinteract) (1.15.0)
# Requirement already satisfied: decorator in /home/calvin/anaconda3/lib/python3.8/site-packages (from traitlets<5,>=4.3->nbinteract) (4.4.2)
# Requirement already satisfied: pygments in /home/calvin/anaconda3/lib/python3.8/site-packages (from nbconvert<6,>=5.3->nbinteract) (2.7.2)
# Requirement already satisfied: defusedxml in /home/calvin/anaconda3/lib/python3.8/site-packages (from nbconvert<6,>=5.3->nbinteract) (0.6.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/calvin/anaconda3/lib/python3.8/site-packages (from nbconvert<6,>=5.3->nbinteract) (1.4.3)
# Requirement already satisfied: entrypoints>=0.2.2 in /home/calvin/anaconda3/lib/python3.8/site-packages (from nbconvert<6,>=5.3->nbinteract) (0.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /home/calvin/anaconda3/lib/python3.8/site-packages (from nbconvert<6,>=5.3->nbinteract) (0.8.4)
# Requirement already satisfied: testpath in /home/calvin/anaconda3/lib/python3.8/site-packages (from nbconvert<6,>=5.3->nbinteract) (0.4.4)
# Requirement already satisfied: bleach in /home/calvin/anaconda3/lib/python3.8/site-packages (from nbconvert<6,>=5.3->nbinteract) (3.2.1)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /home/calvin/anaconda3/lib/python3.8/site-packages (from ipywidgets<8,>=7.5.0->nbinteract) (3.5.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/calvin/anaconda3/lib/python3.8/site-packages (from ipywidgets<8,>=7.5.0->nbinteract) (5.3.4)
# Requirement already satisfied: pandas in /home/calvin/anaconda3/lib/python3.8/site-packages (from bqplot==0.11.0->nbinteract) (1.1.3)
# Collecting traittypes>=0.0.6
#   Using cached traittypes-0.2.1-py2.py3-none-any.whl (8.6 kB)
# Requirement already satisfied: backcall in /home/calvin/anaconda3/lib/python3.8/site-packages (from IPython<8,>=6->nbinteract) (0.2.0)
# Requirement already satisfied: pickleshare in /home/calvin/anaconda3/lib/python3.8/site-packages (from IPython<8,>=6->nbinteract) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/calvin/anaconda3/lib/python3.8/site-packages (from IPython<8,>=6->nbinteract) (3.0.8)
# Requirement already satisfied: setuptools>=18.5 in /home/calvin/anaconda3/lib/python3.8/site-packages (from IPython<8,>=6->nbinteract) (50.3.1.post20201107)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in /home/calvin/anaconda3/lib/python3.8/site-packages (from IPython<8,>=6->nbinteract) (4.8.0)
# Requirement already satisfied: jedi>=0.10 in /home/calvin/anaconda3/lib/python3.8/site-packages (from IPython<8,>=6->nbinteract) (0.17.1)
# Requirement already satisfied: attrs>=17.4.0 in /home/calvin/anaconda3/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat<5,>=4.4.0->nbinteract) (20.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /home/calvin/anaconda3/lib/python3.8/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat<5,>=4.4.0->nbinteract) (0.17.3)
# Requirement already satisfied: packaging in /home/calvin/anaconda3/lib/python3.8/site-packages (from bleach->nbconvert<6,>=5.3->nbinteract) (20.4)
# Requirement already satisfied: webencodings in /home/calvin/anaconda3/lib/python3.8/site-packages (from bleach->nbconvert<6,>=5.3->nbinteract) (0.5.1)
# Requirement already satisfied: notebook>=4.4.1 in /home/calvin/anaconda3/lib/python3.8/site-packages (from widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->nbinteract) (6.1.4)
# Requirement already satisfied: jupyter-client in /home/calvin/anaconda3/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.5.0->nbinteract) (6.1.7)
# Requirement already satisfied: tornado>=4.2 in /home/calvin/anaconda3/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets<8,>=7.5.0->nbinteract) (6.0.4)
# Requirement already satisfied: pytz>=2017.2 in /home/calvin/anaconda3/lib/python3.8/site-packages (from pandas->bqplot==0.11.0->nbinteract) (2020.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/calvin/anaconda3/lib/python3.8/site-packages (from pandas->bqplot==0.11.0->nbinteract) (2.8.1)
# Requirement already satisfied: wcwidth in /home/calvin/anaconda3/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython<8,>=6->nbinteract) (0.2.5)
# Requirement already satisfied: ptyprocess>=0.5 in /home/calvin/anaconda3/lib/python3.8/site-packages (from pexpect>4.3; sys_platform != "win32"->IPython<8,>=6->nbinteract) (0.6.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /home/calvin/anaconda3/lib/python3.8/site-packages (from jedi>=0.10->IPython<8,>=6->nbinteract) (0.7.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/calvin/anaconda3/lib/python3.8/site-packages (from packaging->bleach->nbconvert<6,>=5.3->nbinteract) (2.4.7)
# Requirement already satisfied: pyzmq>=17 in /home/calvin/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->nbinteract) (19.0.2)
# Requirement already satisfied: argon2-cffi in /home/calvin/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->nbinteract) (20.1.0)
# Requirement already satisfied: Send2Trash in /home/calvin/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->nbinteract) (1.5.0)
# Requirement already satisfied: terminado>=0.8.3 in /home/calvin/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->nbinteract) (0.9.1)
# Requirement already satisfied: prometheus-client in /home/calvin/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->nbinteract) (0.8.0)
# Requirement already satisfied: cffi>=1.0.0 in /home/calvin/anaconda3/lib/python3.8/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->nbinteract) (1.14.3)
# Requirement already satisfied: pycparser in /home/calvin/anaconda3/lib/python3.8/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets<8,>=7.5.0->nbinteract) (2.20)
# Installing collected packages: traitlets, nbformat, nbconvert, docopt, traittypes, bqplot, nbinteract
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.0.5
#     Uninstalling traitlets-5.0.5:
#       Successfully uninstalled traitlets-5.0.5
#   Attempting uninstall: nbformat
#     Found existing installation: nbformat 5.0.8
#     Uninstalling nbformat-5.0.8:
#       Successfully uninstalled nbformat-5.0.8
#   Attempting uninstall: nbconvert
#     Found existing installation: nbconvert 6.0.7
#     Uninstalling nbconvert-6.0.7:
#       Successfully uninstalled nbconvert-6.0.7
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# spyder 4.1.5 requires pyqt5<5.13; python_version >= "3", which is not installed.
# spyder 4.1.5 requires pyqtwebengine<5.13; python_version >= "3", which is not installed.
# nbclient 0.5.1 requires nbformat>=5.0, but you'll have nbformat 4.4.0 which is incompatible.
# Successfully installed bqplot-0.11.0 docopt-0.6.2 nbconvert-5.6.1 nbformat-4.4.0 nbinteract-0.2.5 traitlets-4.3.3 traittypes-0.2.1

# %%
# Population of Minnesota in thousands
N = 5300 

# Number of S,I,R from 8/30-9/5 week
R0 = 71.9
I0 = 78.1 - R0
S0 = N - (R0 + I0)



    
# Next we write Euler's method
def eulerStep(S,I,R, h,k1,k2):
    s1 = S - (k1 * S * I / N)
    i1 = I + (k1 * S * I / N) - (k2 * I)
    r1 = R + k2 * I
    return [s1,i1, r1]
    
# Do Euler's method for n weeks
# change index to 0 : healthy, 1: infected, 2: Removed
def eulerNsteps(S0,I0,R0, n,k1,k2):
    total = [[S0,I0,R0]]
    for i in range(n):
        s1 = total[-1][0]
        i1 = total[-1][1]
        r1 = total[-1][2]
        total.append(eulerStep(s1,i1,r1,1,k1,k2))
    return total
        

# key : 0 for healthy 
#       1 for current sick
#       2 for total sick
#       4 for removed 
def plotter(nWeeks, S0, I0, R0, key,k1,k2):
    c1 = k1
    c2 = k2
    # Run for nWeeks
    nsteps = nWeeks
    # indices of x axis
    xs = [i+37 for i in range(nsteps+1)]
    #values for y axis
    predictions = eulerNsteps(S0,I0, R0, nsteps, c1, c2)
    #health, infected, removed, and total infected at each time step
    healths = [i[0] for i in predictions]
    infs = [i[1] for i in predictions]
    totalInfs = [sum(infs[0:i])+78 for i in range(len(infs))]
    rs= [i[2] for i in predictions]
    if(key == 0):
        plt.plot(xs, rs, color="black")
    elif(key == 1):
        plt.plot(xs, infs, color="black")
    elif(key==2):
        plt.plot(xs,totalInfs, color = "blue")
    else:
        plt.plot(xs,rs, color= "green")

#If you comment out interact in the last cell, comment out this too.
interact(plotter, nWeeks=8, S0=S0, I0=I0, R0=R0,key=2, k1 = (0.4,4,0.05), k2 = (0.4,4,0.05))
# Out:
# interactive(children=(IntSlider(value=8, description='nWeeks', max=24, min=-8), FloatSlider(value=5221.9, desc…
# <function __main__.plotter(nWeeks, S0, I0, R0, key, k1, k2)>

# %% [markdown]
# ## Exercise 6
# Play around with initial data and k1,k2 and observe how they change the models predictions.
# You might want to try using actual data. If so [Data for week 45]("https://www.health.state.mn.us/diseases/coronavirus/stats/covidweekly45.pdf"). Replace the 45 by another number at the end of the url to change weeks.
#
# ## Exercise 7
# Is this is a good model? Does it lead to accurate predictions? If not what conceptually do you think this model is missing?
